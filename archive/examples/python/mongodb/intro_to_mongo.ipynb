# %%
import json
import pymongo

# %%
def get_mongo_creds():
    import json
    creds_loc = r"C:\repos\DA320\auth.json"

    with open(creds_loc) as f:
        data = json.load(f)
        conn_str = data['mongodb']

    return conn_str

# %%
def get_mongodb():
    from pymongo import MongoClient
    import pymongo

    conn_str = get_mongo_creds()
    
    
    return client.test

# %%
client = get_mongodb()

# %%
creds_loc = r"C:\repos\DA320\auth.json"

with open(creds_loc) as f:
    data = json.load(f)
    conn_str = data['mongodb']

client = pymongo.MongoClient(conn_str)

# %%
type(client)
# Out:
# pymongo.mongo_client.MongoClient

# %%
db = client.admin

# %%
stat = db.command("serverStatus")
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# c:\mattgraham93.github.io\examples\python\mongodb\intro_to_mongo.ipynb Cell 8' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/mattgraham93.github.io/examples/python/mongodb/intro_to_mongo.ipynb#ch0000006?line=0'>1</a> stat = db.command("serverStatus")
#
# File c:\languages\lib\site-packages\pymongo\database.py:725, in Database.command(self, command, value, check, allowable_errors, read_preference, codec_options, session, comment, **kwargs)
#     <a href='file:///c%3A/languages/lib/site-packages/pymongo/database.py?line=719'>720</a>     read_preference = (session and session._txn_read_preference()) or ReadPreference.PRIMARY
#     <a href='file:///c%3A/languages/lib/site-packages/pymongo/database.py?line=720'>721</a> with self.__client._socket_for_reads(read_preference, session) as (
# ...
