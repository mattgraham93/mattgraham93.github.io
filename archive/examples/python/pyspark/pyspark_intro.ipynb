# %%
# !pip install findspark

# %%
import findspark
import os
from pyspark import SparkConf, SparkContext

# %%
# set variables
os.environ["JAVA_HOME"] = r"C:\LanguagePackages\java8"
os.environ["SPARK_HOME"] = r"C:\LanguagePackages\spark\spark-3.1.3-bin-hadoop3.2"

print(f"---- Initializing spark cluster ----")
findspark.init()
print(f"---- Creating configuration ----")
spark_conf = SparkConf()\
  .setAppName("YourTest")\
  .setMaster("local[*]")
print(f"---- get or create configuration ----")
sc = SparkContext.getOrCreate(spark_conf)
# Out:
# ---- Initializing spark cluster ----
# ---- Creating configuration ----
# ---- get or create configuration ----

# %%
# spark =

# %%
sc
# Out:
# <SparkContext master=local[*] appName=YourTest>

# %%
data = [{"Category": 'A', "ID": 1, "Value": 121.44, "Truth": True},
        {"Category": 'B', "ID": 2, "Value": 300.01, "Truth": False},
        {"Category": 'C', "ID": 3, "Value": 10.99, "Truth": None},
        {"Category": 'E', "ID": 4, "Value": 33.87, "Truth": True}
        ]

# %%
# df =
