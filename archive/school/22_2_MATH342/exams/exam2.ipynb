# %%
import scipy.stats as st

# %%
alpha = 0.05
df_1 = 3
df_2 = 12

crit_val = st.f.ppf(1 - alpha, df_1, df_2)
crit_val
# Out:
# 3.490294819497605

# %%
alpha = 0.05
df_1 = 2
df_2 = 54

crit_val = st.f.ppf(1 - alpha, df_1, df_2)
crit_val
# Out:
# 3.1682459672513357

# %%
alpha = 0.05
df_1 = 1
df_2 = 54

crit_val = st.f.ppf(1 - alpha, df_1, df_2)
crit_val
# Out:
# 4.019540960205442

# %%
alpha = 0.05
df_1 = 2
df_2 = 8

crit_val = st.f.ppf(1 - alpha, df_1, df_2)
crit_val
# Out:
# 4.458970107524511

# %%
alpha = 0.05
df_1 = 4
df_2 = 12

crit_val = st.f.ppf(1 - alpha, df_1, df_2)
crit_val
# Out:
# 3.259166726901249

# %%
alpha = 0.05
df_1 = 2
df_2 = 27

crit_val = st.f.ppf(1 - alpha, df_1, df_2)
crit_val
# Out:
# 3.3541308285291986

# %%
alpha = 0.05
df_1 = 4
df_2 = 27

crit_val = st.f.ppf(1 - alpha, df_1, df_2)
crit_val
# Out:
# 2.7277653060339886

# %%
alpha = 0.05
df_1 = 2
df_2 = 24

crit_val = st.f.ppf(1 - alpha, df_1, df_2)
crit_val
# Out:
# 3.4028261053501945

# %%
alpha = 0.05
df_1 = 1
df_2 = 24

crit_val = st.f.ppf(1 - alpha, df_1, df_2)
crit_val
# Out:
# 4.259677272690231
