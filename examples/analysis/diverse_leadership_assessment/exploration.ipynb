# %%
import pandas as pd
import seaborn as sns

# %%
resp = pd.read_excel(r'C:\repos\data\diverse_leadership_assessment\Confidential Manager Inclusive Feedback Assessment.xlsx')
self_assess = pd.read_excel(r'C:\repos\data\diverse_leadership_assessment\Self-Assessment -_Inclusive Leadership traits and competencies_.xlsx')

# %%
resp.to_csv('responses.csv')

# %%
self_assess.set_index('ManagerID', inplace=True)
self_assess
# Out:
#            Authenticity  Emotional intelligence  Self confidence  Curiosity  \
# ManagerID
# 3                   4.0                     5.0              4.0        5.0
# 4                   5.0                     5.0              5.0        4.0
# 5                   4.0                     3.0              4.0        4.0
# 6                   5.0                     5.0              5.0        4.0
# 7                   4.0                     3.0              5.0        4.0
# 8                   5.0                     5.0              5.0        5.0
# 9                   4.0                     4.0              3.0        5.0
# 10                  4.0                     4.0              5.0        5.0
# 11                  4.0                     4.0              4.0        4.0
# 12                  3.0                     3.0              4.0        3.0
# 13                  4.0                     5.0              5.0        5.0
# ...

# %%
self_assess.to_csv('self_asess.csv')
