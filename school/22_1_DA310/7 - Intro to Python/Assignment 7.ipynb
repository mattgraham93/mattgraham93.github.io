# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

# %%
# create dataframe from csv
df = pd.read_csv('HeartDisease.csv')
# print shape
print(f"Shape: {df.shape}")

# create columns object
col_obj = df.columns  

cols = []  
# iterate through col_obj to make list for graph titles
for col in col_obj:
    cols.append(col)

# show columns
print(f"Columns: {cols}")

# put to array for np operations
df_np = df.to_numpy()
# print(df_np.shape)
# Out:
# Shape: (303, 10)
# Columns: ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'thalach', 'oldpeak', 'ca', 'target']

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  thalach  oldpeak  ca  target
# 0   63    1   3       145   233    1      150      2.3   0       1
# 1   37    1   2       130   250    0      187      3.5   0       1
# 2   41    0   1       130   204    0      172      1.4   0       1
# 3   56    1   1       120   236    0      178      0.8   0       1
# 4   57    0   0       120   354    0      163      0.6   0       1
# 5   57    1   0       140   192    0      148      0.4   0       1
# 6   56    0   1       140   294    0      153      1.3   0       1
# 7   44    1   1       120   263    0      173      0.0   0       1
# 8   52    1   2       172   199    1      162      0.5   0       1
# 9   57    1   2       150   168    0      174      1.6   0       1

# %%
df.tail(8)
# Out:
#      age  sex  cp  trestbps  chol  fbs  thalach  oldpeak  ca  target
# 295   63    1   0       140   187    0      144      4.0   2       0
# 296   63    0   0       124   197    0      136      0.0   0       0
# 297   59    1   0       164   176    1       90      1.0   2       0
# 298   57    0   0       140   241    0      123      0.2   0       0
# 299   45    1   3       110   264    0      132      1.2   0       0
# 300   68    1   0       144   193    1      141      3.4   2       0
# 301   57    1   0       130   131    0      115      1.2   1       0
# 302   57    0   1       130   236    0      174      0.0   1       0

# %%
fig, axes = plt.subplots(nrows=1, ncols=df_np.shape[1], sharex=False, sharey=False, figsize = (16, 3))

for ii in np.arange(0, df_np.shape[1]):
    # print(ii)
    ax = axes[ii]
    # print(ax)
    ax.hist(df_np[:,ii])
    ax.set_title(cols[ii])

plt.show()

# %%
## Bad programming style (spaghetti code), but didn't want to add confusion about looping the features back 
# to the first one
fig, axes = plt.subplots(nrows=df_np.shape[1], ncols=df_np.shape[1], sharex=False, sharey=False, figsize = (16, 16))

for f1 in np.arange (df.shape[1]):
    for f2 in np.arange (df.shape[1]):
        if not f1 == f2:
            ax = axes[f1, f2]
            ax.scatter (df_np[:,f1], df_np[:,f2])
            ax.set_title (cols[f1] + " vs " + cols[f2])
            
plt.show()
