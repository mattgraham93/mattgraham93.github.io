# %% [markdown]
# ## Chapter 3 examples

# %%
x = c(2, 6, 8, 12, -19, 30, 0, -5, 7, 16, 23, 38, -29, 35, 1, -28)
y = c(9,2,-4,42,9,23,-3,-6,5,22,-14,51,65,3,-16,-3)

# %% [markdown]
# #### Central tendency

# %%
mean(x)

# %%
median(x)

# %%
hist(x)

# %%
stem(x)
# Out:
#   The decimal point is 1 digit(s) to the right of the |
#
#   -2 | 98
#   -0 | 95
#    0 | 01267826
#    2 | 3058

# %%
print(sort(x))
# Out:
#  [1] -29 -28 -19  -5   0   1   2   6   7   8  12  16  23  30  35  38

# %%
print(quantile(x, seq(0,1),.1))
# Out:
#   0% 100%
#  -29   38

# %% [markdown]
# #### Variability

# %%
p = c(.1, .24, .68, .93)
print(quantile(x,p))
# Out:
#    10%    24%    68%    93%
# -23.50  -2.00  12.80  34.75

# %%
IQR(x)

# %%
var(x)

# %%
sd(x)

# %% [markdown]
# #### median absolute deviation

# %%
mad(x)

# %%
boxplot(x)

# %%
plot(x,y)

# %%
cor(x,y)

# %% [markdown]
# #### percentile plot

# %%
n = length(x)
i = seq(1:n)
u = (i-.5)/n
s=sort(x)
plot(u, s)

# %% [markdown]
# ## Chapter 4 examples

# %% [markdown]
# #### Random numbers

# %%
y = c(0:9)
x = sample(y, 100, replace=T)
print(x)
# Out:
#   [1] 4 7 9 8 6 4 9 2 2 3 4 1 1 8 3 4 9 7 8 5 5 6 8 9 9 2 1 5 4 6 3 6 0 3 1 4 9
#  [38] 9 3 9 5 2 2 9 5 2 1 0 6 7 1 9 5 5 6 8 2 4 3 6 3 9 0 5 8 4 8 6 6 1 6 0 8 9
#  [75] 4 1 6 4 1 7 3 9 4 8 8 4 3 0 5 9 8 6 3 2 3 5 3 2 7 8

# %% [markdown]
# #### Binomial probabilities
# n = 10, pi = 0.6

# %%
# p(x = 3)
dbinom(3,10,.6)

# %%
# p(x <= 3)
pbinom(3,10,.6)

# %%
# p(x > 4)
1 - pbinom(4,10,.6)

# %%
# calculate k probabilities
k = c(0:10)
print(dbinom(k,10,.6))
# Out:
#  [1] 0.0001048576 0.0015728640 0.0106168320 0.0424673280 0.1114767360
#  [6] 0.2006581248 0.2508226560 0.2149908480 0.1209323520 0.0403107840
# [11] 0.0060466176

# %% [markdown]
# #### Poisson probabilities
# lambda = 10, pi = 0.6

# %%
# p(x = 3)
dbinom(3,10,.6)

# %%
# p(x <= 3)
pbinom(3,10,.6)

# %%
# calculate k probabilities
k = c(0:10)
print(dbinom(k,10,.6))
# Out:
#  [1] 0.0001048576 0.0015728640 0.0106168320 0.0424673280 0.1114767360
#  [6] 0.2006581248 0.2508226560 0.2149908480 0.1209323520 0.0403107840
# [11] 0.0060466176

# %% [markdown]
# #### Normal probabilities
# me = 23, sigma = 5

# %%
pnorm(18,23,5)

# %%
# p(x > 18)
1 - pnorm(18,23,5)

# %%
# find percentile
q(.85, 23, 5)
# Out:
# NULL

# %% [markdown]
# #### Generating sample distribution of y-bar
# Simulates sampling distribution of y-bar. We create 10000 random values of y-bar based on 16 unique observations from
# a population having a normal dist. with me = 43 and sigma = 7

# %%
r = 10000
y = rep(0,16)
ybar16 = rep(0, r)

for (i in 1:r) {
    y = rnorm(16,43,7)
    ybar16[i] = mean(y)
}

# %%
hist(ybar16)

# %%
mean(ybar16)

# %%
sd(ybar16)

# %% [markdown]
# #### Generate plot in figure 4.28

# %%
y = c(133, 137, 148, 149, 152, 167, 174, 179, 189, 192, 201, 209, 210, 211, 218, 238, 245, 248, 253, 257)
sort(y)

# %%
n = length(y)
i = 1:n
u = (i - .375)/(n+.25)
x = qnorm(u)

plot(x,y, xlab = "Normal quantiles", ylab = "Cholesterol readings", lab = c(7,8,7),
    ylim = c(100,280), main = "Normal Reference Distribution Plot\n Cholesterol readings", cex = .95)
abline(lm(y ~ x))

# %%
cor(x,y)
