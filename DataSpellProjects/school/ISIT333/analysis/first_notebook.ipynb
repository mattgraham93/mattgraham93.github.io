# %%
print("test")
# Out:
# test

# %%
print("test")
# Out:
# test

# %%
print("test")
# Out:
# test

# %%
print("test")
# Out:
# test

# %% [markdown]
# This is a markdown thing

# %% [markdown]
# So is this

# %% [markdown]
# And this?
# Yes

# %%
print()

# %% [markdown]
# asdf
