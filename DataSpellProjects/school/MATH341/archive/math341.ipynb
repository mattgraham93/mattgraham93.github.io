# %%
import math

from scipy import stats
import matplotlib.pyplot as plt
import numpy as np
import itertools

# %%
np.math.factorial(4)
# Out:
# 24

# %%
com = itertools.combinations(range(10000),3)

count = 0
for val in com:
    count += 1
print(count)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-59f967a88756> in <module>
#       2
#       3 count = 0
# ----> 4 for val in com:
#       5     count += 1
#       6 print(count)
#
# KeyboardInterrupt:
