# %%
import pandas as pd
import openpyxl
import states
import scipy.stats as st
import numpy as np

# %%
# !pip install openpyxl

# %%
# read in files
gdp = pd.read_csv("gdp_by_state.csv")
legislators = pd.read_csv("legislators-current.csv")
states_df = pd.Series(states.us_state_to_abbrev).reset_index()

# %%
# rename gdp fields when needed, review quarters --> states are names
gdp.rename(columns={'Unnamed: 1': 'Currency'}, inplace=True)
gdp
# Out:
#     GeoFips               GeoName       1997       1998       1999       2000  \
# 0      1000               Alabama   104811.9   110212.0   115680.1   119851.7
# 1      2000                Alaska    25810.8    24227.5    24744.3    26806.6
# 2      4000               Arizona   132281.0   143302.6   155755.8   165110.7
# 3      5000              Arkansas    59846.3    62396.7    66811.3    68678.5
# 4      6000            California  1071117.0  1147520.4  1241899.7  1356975.4
# 5      8000              Colorado   136898.7   150330.0   163763.3   180063.2
# 6      9000           Connecticut   138331.8   145475.5   152287.5   165614.3
# 7     10000              Delaware    33353.4    37106.0    40345.1    43451.3
# 8     11000  District of Columbia    52503.6    54815.3    58819.2    61092.9
# 9     12000               Florida   401535.3   429138.4   458058.9   490429.8
# 10    13000               Georgia   242540.8   265347.2   289187.9   305572.0
# 11    15000                Hawaii    37707.4    37622.9    38990.6    41096.8
# 12    16000                 Idaho    29496.9    31059.8    34239.9    38083.1
# 13    17000              Illinois   415534.8   436567.1   460331.1   487014.6
# 14    18000               Indiana   170431.9   184359.8   193147.3   203801.1
# 15    19000                  Iowa    82720.4    84644.0    87782.4    93112.0
# 16    20000                Kansas    74662.3    78382.0    81883.8    86099.0
# 17    21000              Kentucky   104546.2   109382.3   115106.8   114169.2
# 18    22000             Louisiana   116313.2   120198.1   125807.3   132640.8
# 19    23000                 Maine    30618.4    32156.2    34413.2    36890.3
# 20    24000              Maryland   159372.1   169982.1   180261.6   192021.4
# 21    25000         Massachusetts   237267.4   249299.0   264644.4   288791.0
# 22    26000              Michigan   299817.7   312688.1   338312.4   352152.4
# 23    27000             Minnesota   156351.4   166904.8   175759.3   191515.0
# 24    28000           Mississippi    58352.7    60940.4    63879.0    65673.1
# 25    29000              Missouri   163175.6   169483.4   177738.0   186650.0
# 26    30000               Montana    19290.4    20429.1    20812.2    21876.7
# 27    31000              Nebraska    49819.2    51822.1    53685.2    56527.5
# 28    32000                Nevada    60259.1    65114.2    71595.9    76833.1
# 29    33000         New Hampshire    38206.6    40554.0    41955.2    45342.0
# 30    34000            New Jersey   307817.1   319861.3   336064.9   361005.4
# 31    35000            New Mexico    52475.6    50658.7    53017.3    55105.0
# 32    36000              New York   718814.3   745502.4   795230.0   841181.3
# 33    37000        North Carolina   233934.9   246890.4   265375.7   278008.5
# 34    38000          North Dakota    15760.8    16816.6    17067.2    18100.1
# 35    39000                  Ohio   343430.3   361638.1   376465.2   392277.2
# 36    40000              Oklahoma    79044.4    81196.9    84223.9    91093.9
# 37    41000                Oregon   100914.8   105146.8   107621.5   117154.6
# 38    42000          Pennsylvania   356988.0   373748.5   390916.8   409159.9
# 26    51789.3    51508.8
# 27   131352.4   133439.0
# 28   181743.3   170943.8
# 29    87507.6    87621.0
# 30   639436.7   618579.3
# 31   101971.5    98472.1
# 32  1777751.8  1724759.1
# 33   595655.4   589829.0
# 34    59004.5    54854.2
# 35   693199.3   677561.2
# 36   203699.7   188056.6
# 37   246647.1   243776.8
# 38   799686.2   771897.9
# 39    61319.1    60556.3
# 40   244662.3   244881.7
# 41    53939.9    54789.4
# 42   376916.5   369574.3
# 43  1863953.8  1775587.8
# 44   195088.4   197561.9
# 45    34127.5    33435.0
# 46   554305.8   549535.8
# 47   597873.8   604253.8
# 48    79139.7    75855.0
# 49   344724.8   337714.0
# 50    39600.8    36323.5
#
# [51 rows x 26 columns]

# %%
t_gdp = gdp.T
t_gdp.columns = gdp.GeoName
t_gdp = t_gdp[2:]
# t_gdp['Washginton'].sum().sort_values(ascending=False).plot(kind='bar', figsize=(10,8))

# %%
# look at legislators --> states are abbreviations
legislators
# Out:
#                last_name first_name middle_name suffix nickname  \
# 0                  Brown    Sherrod         NaN    NaN      NaN
# 1               Cantwell      Maria         NaN    NaN      NaN
# 2                 Cardin   Benjamin          L.    NaN      NaN
# 3                 Carper     Thomas     Richard    NaN      NaN
# 4                  Casey     Robert          P.    Jr.      Bob
# ..                   ...        ...         ...    ...      ...
# 535            Stansbury    Melanie         Ann    NaN      NaN
# 536               Ellzey       Jake         NaN    NaN      NaN
# 537                Brown    Shontel          M.    NaN      NaN
# 538                Carey       Mike         NaN    NaN      NaN
# 539  Cherfilus-McCormick     Sheila         NaN    NaN      NaN
#
#                       full_name    birthday gender type state  ...  \
# 0                 Sherrod Brown  1952-11-09      M  sen    OH  ...
# 1                Maria Cantwell  1958-10-13      F  sen    WA  ...
# 2            Benjamin L. Cardin  1943-10-05      M  sen    MD  ...
# 3              Thomas R. Carper  1947-01-23      M  sen    DE  ...
# 4          Robert P. Casey, Jr.  1960-04-13      M  sen    PA  ...
# ..                          ...         ...    ...  ...   ...  ...
# 535        Melanie A. Stansbury  1979-01-31      F  rep    NM  ...
# 536                 Jake Ellzey  1970-01-24      M  rep    TX  ...
# 537            Shontel M. Brown  1975-06-24      F  rep    OH  ...
# 538                  Mike Carey  1971-03-13      M  rep    OH  ...
# 539  Sheila Cherfilus-McCormick  1979-01-25      F  rep    FL  ...
#
#      opensecrets_id  lis_id              fec_ids cspan_id govtrack_id  \
# 0         N00003535    S307  H2OH13033,S6OH00163   5051.0      400050
# 1         N00007836    S275  S8WA00194,H2WA01054  26137.0      300018
# 2         N00001955    S308  H6MD03177,S6MD03177   4004.0      400064
# 3         N00012508    S277            S8DE00079    663.0      300019
# 4         N00027503    S309            S6PA00217  47036.0      412246
# ..              ...     ...                  ...      ...         ...
# 535       N00047871     NaN            H2NM01144      NaN      456861
# 536             NaN     NaN            H8TX06266      NaN      456862
# 537             NaN     NaN            H2OH11169      NaN      456863
# 538             NaN     NaN            H2OH15228      NaN      456864
# 539             NaN     NaN            H8FL20032      NaN      456865
#
#     votesmart_id         ballotpedia_id washington_post_id icpsr_id  \
# 0        27018.0          Sherrod Brown                NaN  29389.0
# 1        27122.0         Maria Cantwell                NaN  39310.0
# 2        26888.0             Ben Cardin                NaN  15408.0
# 3        22421.0             Tom Carper                NaN  15015.0
# 4         2541.0         Bob Casey, Jr.                NaN  40703.0
# ..           ...                    ...                ...      ...
# 535          NaN  Melanie Ann Stansbury                NaN      NaN
# 536          NaN            Jake Ellzey                NaN      NaN
# 537          NaN                    NaN                NaN      NaN
# 538          NaN                    NaN                NaN      NaN
# 539          NaN                    NaN                NaN      NaN
#
#                    wikipedia_id
# 0                 Sherrod Brown
# 1                Maria Cantwell
# 2                    Ben Cardin
# 3                    Tom Carper
# 4                 Bob Casey Jr.
# ..                          ...
# 535           Melanie Stansbury
# 536                 Jake Ellzey
# 537               Shontel Brown
# 538     Mike Carey (politician)
# 539  Sheila Cherfilus-McCormick
#
# [540 rows x 34 columns]

# %%
states_df.columns = ['StateName', 'StateAbbrev']
states_df
# Out:
#                                StateName StateAbbrev
# 0                                Alabama          AL
# 1                                 Alaska          AK
# 2                                Arizona          AZ
# 3                               Arkansas          AR
# 4                             California          CA
# 5                               Colorado          CO
# 6                            Connecticut          CT
# 7                               Delaware          DE
# 8                                Florida          FL
# 9                                Georgia          GA
# 10                                Hawaii          HI
# 11                                 Idaho          ID
# 12                              Illinois          IL
# 13                               Indiana          IN
# 14                                  Iowa          IA
# 15                                Kansas          KS
# 16                              Kentucky          KY
# 17                             Louisiana          LA
# 18                                 Maine          ME
# 19                              Maryland          MD
# 20                         Massachusetts          MA
# 21                              Michigan          MI
# 22                             Minnesota          MN
# 23                           Mississippi          MS
# 24                              Missouri          MO
# 25                               Montana          MT
# 26                              Nebraska          NE
# 27                                Nevada          NV
# 28                         New Hampshire          NH
# 29                            New Jersey          NJ
# 30                            New Mexico          NM
# 31                              New York          NY
# 32                        North Carolina          NC
# 33                          North Dakota          ND
# 34                                  Ohio          OH
# 35                              Oklahoma          OK
# 36                                Oregon          OR
# 37                          Pennsylvania          PA
# 38                          Rhode Island          RI
# 39                        South Carolina          SC
# 40                          South Dakota          SD
# 41                             Tennessee          TN
# 42                                 Texas          TX
# 43                                  Utah          UT
# 44                               Vermont          VT
# 45                              Virginia          VA
# 46                            Washington          WA
# 47                         West Virginia          WV
# 48                             Wisconsin          WI
# 49                               Wyoming          WY
# 50                  District of Columbia          DC
# 51                        American Samoa          AS
# 52                                  Guam          GU
# 53              Northern Mariana Islands          MP
# 54                           Puerto Rico          PR
# 55  United States Minor Outlying Islands          UM
# 56                   U.S. Virgin Islands          VI

# %%
len(legislators)
# Out:
# 540

# %%
# un_vals = pd.DataFrame(columns=['column', 'unique val', 'count'])

# for col in legislators.columns:
#     small_df = pd.DataFrame()
#     small_df['column'] = col
#     small_df['unique val'] = legislators[col].unique()
#     small_df['count'] = legislators[col].value_counts()
#     un_vals = pd.concat([un_vals, small_df])

# for col in legislators.columns.to_series():
#     col_vals = pd.DataFrame(legislators[col].unique())
    # un_vals = pd.concat([un_vals, col_vals])
# un_vals
# col_vals

# %%
legislators.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540 entries, 0 to 539
# Data columns (total 34 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   last_name           540 non-null    object
#  1   first_name          540 non-null    object
#  2   middle_name         247 non-null    object
#  3   suffix              18 non-null     object
#  4   nickname            42 non-null     object
#  5   full_name           540 non-null    object
#  6   birthday            540 non-null    object
#  7   gender              540 non-null    object
#  8   type                540 non-null    object
#  9   state               540 non-null    object
#  10  district            440 non-null    float64
#  11  senate_class        100 non-null    float64
#  12  party               540 non-null    object
#  13  url                 537 non-null    object
#  14  address             540 non-null    object
#  15  phone               540 non-null    object
#  16  contact_form        100 non-null    object
#  17  rss_url             254 non-null    object
#  18  twitter             523 non-null    object
#  19  facebook            373 non-null    object
#  20  youtube             265 non-null    object
#  21  youtube_id          341 non-null    object
#  22  bioguide_id         540 non-null    object
#  23  thomas_id           328 non-null    float64
#  24  opensecrets_id      536 non-null    object
#  25  lis_id              100 non-null    object
#  26  fec_ids             540 non-null    object
#  27  cspan_id            381 non-null    float64
#  28  govtrack_id         540 non-null    int64
#  29  votesmart_id        475 non-null    float64
#  30  ballotpedia_id      492 non-null    object
#  31  washington_post_id  0 non-null      float64
#  32  icpsr_id            460 non-null    float64
#  33  wikipedia_id        539 non-null    object
# dtypes: float64(7), int64(1), object(26)
# memory usage: 143.6+ KB

# %%
legislators.groupby('state').size().sort_values(ascending=False).plot(kind='bar', figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='state'>

# %%
gdpt = gdp_dollars.transpose()
new_header = gdpt.iloc[0] #grab the first row for the header
gdpt = gdpt[1:] #take the data less the header row
gdpt.columns = new_header #set the header row as the df header
gdpt = gdpt[1:] # remove currency row
gdpt
# Out:
# State  Connecticut   Maine  Massachusetts  New Hampshire  Rhode Island   \
# 2020Q1    286287.0  70099.0       600436.0        89251.0       61776.0
# 2020Q2    257812.0  64704.0       544140.0        80750.0       56289.0
# 2020Q3    278870.0  70256.0       586020.0        88890.0       61653.0
# 2020Q4    282722.0  72027.0       599311.0        91593.0       62508.0
# 2021Q1    285112.0  73174.0       610700.0        92753.0       62340.0
# 2021Q2    293595.0  75214.0       629570.0        98746.0       65700.0
# 2021Q3    298612.0  76664.0       642038.0        99030.0       66894.0
#
# State  Vermont  Delaware  District of Columbia  Maryland  New Jersey  ...  \
# 2020Q1  34688.0   77074.0              147340.0  422760.0   646387.0  ...
# 2020Q2  30758.0   71818.0              139171.0  387607.0   571006.0  ...
# 2020Q3  33897.0   76815.0              144287.0  415082.0   624873.0  ...
# 2020Q4  34397.0   77439.0              147421.0  417251.0   632051.0  ...
# 2021Q1  35032.0   77392.0              147830.0  430607.0   649336.0  ...
# 2021Q2  35703.0   79728.0              150577.0  431319.0   661895.0  ...
# 2021Q3  36302.0   81546.0              153168.0  439028.0   677006.0  ...
#
# State  Montana      Utah  Wyoming   Alaska  California   Hawaii     Nevada  \
# 2020Q1  51948.0  196920.0  38834.0  53103.0   3083611.0  90324.0  184994.0
# 2020Q2  47992.0  186766.0  33215.0  45945.0   2801947.0  77670.0  151094.0
# 2020Q3  52341.0  200044.0  36181.0  48877.0   3042208.0  81035.0  172158.0
# 2020Q4  53755.0  206518.0  37064.0  51355.0   3100985.0  82509.0  175529.0
# 2021Q1  56453.0  211721.0  39303.0  52164.0   3207139.0  84183.0  180973.0
# 2021Q2  58755.0  217148.0  40761.0  54056.0   3321704.0  89170.0  190799.0
# 2021Q3  60020.0  222157.0  42102.0  55677.0   3384335.0  91947.0  195777.0
#
# State    Oregon  Washington Overseas activity 1/
# 2020Q1  250597.0   609026.0             133566.0
# 2020Q2  228542.0   568716.0             132517.0
# 2020Q3  246357.0   619197.0             132066.0
# 2020Q4  249611.0   620076.0             136663.0
# 2021Q1  256567.0   636347.0             138201.0
# 2021Q2  262917.0   663121.0             142125.0
# 2021Q3  268864.0   674091.0             146180.0
#
# [7 rows x 52 columns]

# %%
state_gdp = gdpt.sum().reset_index()
state_gdp
# Out:
#                     State           0
# 0             Connecticut   1983010.0
# 1                  Maine     502138.0
# 2          Massachusetts    4212215.0
# 3          New Hampshire     641013.0
# 4           Rhode Island     437160.0
# 5                Vermont     240777.0
# 6               Delaware     541812.0
# 7   District of Columbia    1029794.0
# 8               Maryland    2943654.0
# 9              New Jersey   4462554.0
# 10               New York  12400532.0
# 11          Pennsylvania    5570456.0
# 12              Illinois    6213371.0
# 13                Indiana   2744692.0
# 14              Michigan    3741784.0
# 15                  Ohio    4891042.0
# 16             Wisconsin    2434671.0
# 17                  Iowa    1430741.0
# 18                 Kansas   1271490.0
# 19             Minnesota    2713569.0
# 20              Missouri    2384171.0
# 21               Nebraska    981159.0
# 22          North Dakota     406592.0
# 23          South Dakota     401170.0
# 24               Alabama    1638490.0
# 25               Arkansas    950702.0
# 26               Florida    8043246.0
# 27               Georgia    4509772.0
# 28               Kentucky   1543672.0
# 29             Louisiana    1695849.0
# 30           Mississippi     825849.0
# 31        North Carolina    4294653.0
# 32        South Carolina    1778090.0
# 33             Tennessee    2712424.0
# 34              Virginia    3950794.0
# 35         West Virginia     561046.0
# 36               Arizona    2709824.0
# 37             New Mexico    714921.0
# 38               Oklahoma   1360664.0
# 39                  Texas  12939044.0
# 40              Colorado    2777200.0
# 41                 Idaho     614098.0
# 42               Montana     381264.0
# 43                  Utah    1441274.0
# 44               Wyoming     267460.0
# 45                Alaska     361177.0
# 46            California   21941929.0
# 47                Hawaii     596838.0
# 48                 Nevada   1251324.0
# 49                Oregon    1763455.0
# 50             Washington   4390574.0
# 51   Overseas activity 1/    961318.0

# %%
# state_gdp
gdp_2020 = gdpt.iloc[0:3].sum()
gdp_2021 = gdpt.iloc[4:8].sum()

# %%
gdp_summary = pd.concat([gdp_2020, gdp_2021], axis=1, join="inner")
gdp_summary = gdp_summary.sort_values(by="State")
gdp_summary.columns = ["2020", "2021"]
gdp_summary
# Out:
#                             2020       2021
# State
# Alabama                 673950.0   730904.0
# Alaska                  147925.0   161897.0
# Arizona                1105868.0  1214949.0
# Arkansas                388468.0   427699.0
# California             8927766.0  9913178.0
# Colorado               1139212.0  1246862.0
# Connecticut             822969.0   877319.0
# Delaware                225707.0   238666.0
# District of Columbia    430798.0   451575.0
# Florida                3288321.0  3619103.0
# Georgia                1853158.0  2019260.0
# Hawaii                  249029.0   265300.0
# Idaho                   247588.0   278812.0
# Illinois               2556264.0  2779904.0
# Indiana                1112247.0  1243346.0
# Iowa                    575346.0   653671.0
# Kansas                  519749.0   570923.0
# Kentucky                630623.0   693513.0
# Louisiana               703578.0   754100.0
# Maine                   205059.0   225052.0
# Maryland               1225449.0  1300954.0
# Massachusetts          1730596.0  1882308.0
# Michigan               1527702.0  1681304.0
# Minnesota              1111862.0  1218612.0
# Mississippi             337345.0   370467.0
# Missouri                977369.0  1066703.0
# Montana                 152281.0   175228.0
# Nebraska                393531.0   447402.0
# Nevada                  508246.0   567549.0
# New Hampshire           258891.0   290529.0
# New Jersey             1842266.0  1988237.0
# New Mexico              293243.0   321033.0
# New York               5143659.0  5501496.0
# North Carolina         1751538.0  1935337.0
# North Dakota            163523.0   187176.0
# Ohio                   2012377.0  2180797.0
# Oklahoma                560543.0   608438.0
# Oregon                  725496.0   788348.0
# Overseas activity 1/    398149.0   426506.0
# Pennsylvania           2294354.0  2482865.0
# Rhode Island            179718.0   194934.0
# South Carolina          725747.0   798562.0
# South Dakota            162009.0   182013.0
# Tennessee              1093835.0  1234127.0
# Texas                  5277305.0  5836694.0
# Utah                    583730.0   651026.0
# Vermont                  99343.0   107037.0
# Virginia               1632542.0  1752650.0
# Washington             1796939.0  1973559.0
# West Virginia           223721.0   257626.0
# Wisconsin              1002226.0  1083816.0
# Wyoming                 108230.0   122166.0

# %%
gdp_summary = gdp_summary.merge(states_df, how="inner", left_on="State", right_on="StateName")
gdp_summary

validated_states = gdp_summary.StateName.values
validated_states
# Out:
# array(['Arkansas', 'Connecticut', 'Indiana', 'Kansas', 'Kentucky',
#        'Nebraska', 'Nevada', 'New Jersey', 'New Mexico', 'New York',
#        'Oklahoma', 'Texas', 'Washington'], dtype=object)

# %%
# gdp_melt = gdp.melt()
# gdp_melt

# %%
gdp_trash = pd.concat([gdp_summary, states_df])
gdp_trash.drop(columns="StateName", inplace=True)
gdp_trash
# Out:
#          2020       2021 StateAbbrev
# 0    388468.0   427699.0          AR
# 1    822969.0   877319.0          CT
# 2   1112247.0  1243346.0          IN
# 3    519749.0   570923.0          KS
# 4    630623.0   693513.0          KY
# ..        ...        ...         ...
# 52        NaN        NaN          GU
# 53        NaN        NaN          MP
# 54        NaN        NaN          PR
# 55        NaN        NaN          UM
# 56        NaN        NaN          VI
#
# [70 rows x 3 columns]

# %%
# len(legislators)

legislators
# Out:
#                last_name first_name middle_name suffix nickname  \
# 0                  Brown    Sherrod         NaN    NaN      NaN
# 1               Cantwell      Maria         NaN    NaN      NaN
# 2                 Cardin   Benjamin          L.    NaN      NaN
# 3                 Carper     Thomas     Richard    NaN      NaN
# 4                  Casey     Robert          P.    Jr.      Bob
# ..                   ...        ...         ...    ...      ...
# 535            Stansbury    Melanie         Ann    NaN      NaN
# 536               Ellzey       Jake         NaN    NaN      NaN
# 537                Brown    Shontel          M.    NaN      NaN
# 538                Carey       Mike         NaN    NaN      NaN
# 539  Cherfilus-McCormick     Sheila         NaN    NaN      NaN
#
#                       full_name    birthday gender type state  ...  \
# 0                 Sherrod Brown  1952-11-09      M  sen    OH  ...
# 1                Maria Cantwell  1958-10-13      F  sen    WA  ...
# 2            Benjamin L. Cardin  1943-10-05      M  sen    MD  ...
# 3              Thomas R. Carper  1947-01-23      M  sen    DE  ...
# 4          Robert P. Casey, Jr.  1960-04-13      M  sen    PA  ...
# ..                          ...         ...    ...  ...   ...  ...
# 535        Melanie A. Stansbury  1979-01-31      F  rep    NM  ...
# 536                 Jake Ellzey  1970-01-24      M  rep    TX  ...
# 537            Shontel M. Brown  1975-06-24      F  rep    OH  ...
# 538                  Mike Carey  1971-03-13      M  rep    OH  ...
# 539  Sheila Cherfilus-McCormick  1979-01-25      F  rep    FL  ...
#
#      opensecrets_id  lis_id              fec_ids cspan_id govtrack_id  \
# 0         N00003535    S307  H2OH13033,S6OH00163   5051.0      400050
# 1         N00007836    S275  S8WA00194,H2WA01054  26137.0      300018
# 2         N00001955    S308  H6MD03177,S6MD03177   4004.0      400064
# 3         N00012508    S277            S8DE00079    663.0      300019
# 4         N00027503    S309            S6PA00217  47036.0      412246
# ..              ...     ...                  ...      ...         ...
# 535       N00047871     NaN            H2NM01144      NaN      456861
# 536             NaN     NaN            H8TX06266      NaN      456862
# 537             NaN     NaN            H2OH11169      NaN      456863
# 538             NaN     NaN            H2OH15228      NaN      456864
# 539             NaN     NaN            H8FL20032      NaN      456865
#
#     votesmart_id         ballotpedia_id washington_post_id icpsr_id  \
# 0        27018.0          Sherrod Brown                NaN  29389.0
# 1        27122.0         Maria Cantwell                NaN  39310.0
# 2        26888.0             Ben Cardin                NaN  15408.0
# 3        22421.0             Tom Carper                NaN  15015.0
# 4         2541.0         Bob Casey, Jr.                NaN  40703.0
# ..           ...                    ...                ...      ...
# 535          NaN  Melanie Ann Stansbury                NaN      NaN
# 536          NaN            Jake Ellzey                NaN      NaN
# 537          NaN                    NaN                NaN      NaN
# 538          NaN                    NaN                NaN      NaN
# 539          NaN                    NaN                NaN      NaN
#
#                    wikipedia_id
# 0                 Sherrod Brown
# 1                Maria Cantwell
# 2                    Ben Cardin
# 3                    Tom Carper
# 4                 Bob Casey Jr.
# ..                          ...
# 535           Melanie Stansbury
# 536                 Jake Ellzey
# 537               Shontel Brown
# 538     Mike Carey (politician)
# 539  Sheila Cherfilus-McCormick
#
# [540 rows x 34 columns]

# %%
joined_leg = legislators.merge(gdp_trash, how="left", left_on="state", right_on="StateAbbrev")

#expect 540 rows returned
len(joined_leg)
# Out:
# 694

# %%
joined_leg
# Out:
#                last_name first_name middle_name suffix nickname  \
# 0                  Brown    Sherrod         NaN    NaN      NaN
# 1               Cantwell      Maria         NaN    NaN      NaN
# 2               Cantwell      Maria         NaN    NaN      NaN
# 3                 Cardin   Benjamin          L.    NaN      NaN
# 4                 Carper     Thomas     Richard    NaN      NaN
# ..                   ...        ...         ...    ...      ...
# 689               Ellzey       Jake         NaN    NaN      NaN
# 690               Ellzey       Jake         NaN    NaN      NaN
# 691                Brown    Shontel          M.    NaN      NaN
# 692                Carey       Mike         NaN    NaN      NaN
# 693  Cherfilus-McCormick     Sheila         NaN    NaN      NaN
#
#                       full_name    birthday gender type state  ...  cspan_id  \
# 0                 Sherrod Brown  1952-11-09      M  sen    OH  ...    5051.0
# 1                Maria Cantwell  1958-10-13      F  sen    WA  ...   26137.0
# 2                Maria Cantwell  1958-10-13      F  sen    WA  ...   26137.0
# 3            Benjamin L. Cardin  1943-10-05      M  sen    MD  ...    4004.0
# 4              Thomas R. Carper  1947-01-23      M  sen    DE  ...     663.0
# ..                          ...         ...    ...  ...   ...  ...       ...
# 689                 Jake Ellzey  1970-01-24      M  rep    TX  ...       NaN
# 690                 Jake Ellzey  1970-01-24      M  rep    TX  ...       NaN
# 691            Shontel M. Brown  1975-06-24      F  rep    OH  ...       NaN
# 692                  Mike Carey  1971-03-13      M  rep    OH  ...       NaN
# 693  Sheila Cherfilus-McCormick  1979-01-25      F  rep    FL  ...       NaN
#
#      govtrack_id votesmart_id  ballotpedia_id washington_post_id icpsr_id  \
# 0         400050      27018.0   Sherrod Brown                NaN  29389.0
# 1         300018      27122.0  Maria Cantwell                NaN  39310.0
# 2         300018      27122.0  Maria Cantwell                NaN  39310.0
# 3         400064      26888.0      Ben Cardin                NaN  15408.0
# 4         300019      22421.0      Tom Carper                NaN  15015.0
# ..           ...          ...             ...                ...      ...
# 689       456862          NaN     Jake Ellzey                NaN      NaN
# 690       456862          NaN     Jake Ellzey                NaN      NaN
# 691       456863          NaN             NaN                NaN      NaN
# 692       456864          NaN             NaN                NaN      NaN
# 693       456865          NaN             NaN                NaN      NaN
#
#                    wikipedia_id       2020       2021 StateAbbrev
# 0                 Sherrod Brown        NaN        NaN          OH
# 1                Maria Cantwell  1796939.0  1973559.0          WA
# 2                Maria Cantwell        NaN        NaN          WA
# 3                    Ben Cardin        NaN        NaN          MD
# 4                    Tom Carper        NaN        NaN          DE
# ..                          ...        ...        ...         ...
# 689                 Jake Ellzey  5277305.0  5836694.0          TX
# 690                 Jake Ellzey        NaN        NaN          TX
# 691               Shontel Brown        NaN        NaN          OH
# 692     Mike Carey (politician)        NaN        NaN          OH
# 693  Sheila Cherfilus-McCormick        NaN        NaN          FL
#
# [694 rows x 37 columns]

# %%
joined_leg.groupby('gender').size().sort_values(ascending=False).plot(kind='bar', figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='gender'>
